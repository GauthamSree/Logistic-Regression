# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sns.set_style('whitegrid')
sns.scatterplot(x='area_mean', y='perimeter_mean', hue = 'diagnosis',data=df, alpha=0.8);

# %%
sns.scatterplot(x='concavity_mean', y='compactness_mean', hue='diagnosis', data=df);

# %%
sns.scatterplot(x='radius_worst', y='radius_mean', hue='diagnosis', data=df);

# %%
sns.scatterplot(x='concavity_mean', y='symmetry_mean', hue='diagnosis', data=df);

# %%
m = plt.hist(df[df["diagnosis"] == "M"]['radius_mean'],bins=30,fc = (1,0,0,0.5),label = "Malignant")
b = plt.hist(df[df["diagnosis"] == "B"]['radius_mean'],bins=30,fc = (0,1,0,0.5),label = "Bening")
plt.legend()
plt.xlabel("Radius Mean Values")
plt.ylabel("Frequency")
plt.title("Histogram of Radius Mean for Bening and Malignant Tumors");

# %%
df['diagnosis'] = df['diagnosis'].apply(lambda x: 0 if x=='B' else 1)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Spliting the Data & Normalizing

# %%
train_idx = round(len(df)*0.6)
valid_idx = train_idx + (len(df) - train_idx)//2

# %%
idxs  = np.random.permutation(len(df))

# %%
train, valid, test = df.iloc[idxs[:train_idx]], df.iloc[idxs[train_idx:valid_idx]], df.iloc[idxs[valid_idx:]]

# %%
train.shape, valid.shape, test.shape
# Out:
# ((341, 31), (114, 31), (114, 31))

# %%
train_mean = train.drop('diagnosis', axis = 1).mean()
train_std = train.drop('diagnosis', axis = 1).std()

# %%
def normalize(df_1, mean, std, skip_fld=None):
    df = df_1.copy()
    if skip_fld is None:
        df = (df - mean)/(1e-7 + std)
    else:
        y = df[skip_fld]
        df.drop('diagnosis', axis = 1, inplace = True)
        df = (df - mean)/(1e-7 + std)
        df = pd.concat([df, y], axis = 1)
    return df

# %%
train = normalize(train, train_mean, train_std, 'diagnosis')
valid = normalize(valid, train_mean, train_std, 'diagnosis')
test = normalize(test, train_mean, train_std, 'diagnosis')

# %%
train.to_csv('data/train.csv', index=False)
valid.to_csv('data/valid.csv', index=False)
test.to_csv('data/test.csv', index=False)

# %%
train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 192    -1.269702     -0.270995       -1.307616  -1.079473        -2.000866
# 337     1.314044      0.483741        1.259841   1.272737        -0.447293
# 143    -0.361822     -0.811772       -0.357364  -0.423757        -0.762168
# 292    -0.347548     -0.788260       -0.382142  -0.419368         0.222622
# 232    -0.841457      3.394530       -0.892165  -0.790677        -1.405545
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 192         -1.552722       -1.134029            -1.289371      -0.595824
# 337          0.573237        0.134964             0.234981       0.430300
# 143         -0.248123       -0.548137            -0.516432      -0.168272
# 292         -0.533259       -0.397175            -0.445847      -0.332452
# 232         -1.328765       -1.074566            -1.128326       0.060895
#
# ...
